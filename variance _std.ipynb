# %% [markdown]
# <a href="https://colab.research.google.com/github/100004206Nagarjunayadav/Statistical-toolbox/blob/main/variance%20_std.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

data = [10, 12, 23, 23, 16, 23, 21, 16]

# Variance
variance = np.var(data)
print("Variance:", variance)

# Standard Deviation
std_dev = np.std(data)
print("Standard Deviation:", std_dev)
# Out:
# Variance: 24.0
# Standard Deviation: 4.898979485566356

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data = [10, 12, 23, 23, 16, 23, 21, 16]

# Boxplot
sns.boxplot(data=data, color='lightcoral')
plt.title("Boxplot to Show Spread (Variance & SD)")
plt.xlabel("Values")
plt.show()
